# %%
#pip install gpt4all

# %%
x = 'zhang'

# %%
from llama_cpp import Llama

llm = Llama(
      model_path=r"C:\Users\Yuan\AppData\Local\nomic.ai\GPT4All\Meta-Llama-3-8B-Instruct.Q4_0.gguf",
      # n_gpu_layers=-1, # Uncomment to use GPU acceleration
      # seed=1337, # Uncomment to set a specific seed
      # n_ctx=2048, # Uncomment to increase the context window
)
output = llm(
      "Q: Name the planets in the solar system? A: ", # Prompt
      max_tokens=32, # Generate up to 32 tokens, set to None to generate up to the end of the context window
      stop=["Q:", "\n"], # Stop generating just before the model would generate a new question
      echo=True # Echo the prompt back in the output
) # Generate a completion, can also call create_completion
print(output)
# Out:
# llama_model_loader: loaded meta data with 23 key-value pairs and 291 tensors from C:\Users\Yuan\AppData\Local\nomic.ai\GPT4All\Meta-Llama-3-8B-Instruct.Q4_0.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = dl
# llama_model_loader: - kv   2:                           llama.vocab_size u32              = 128256
# llama_model_loader: - kv   3:                       llama.context_length u32              = 8192
# llama_model_loader: - kv   4:                     llama.embedding_length u32              = 4096
# llama_model_loader: - kv   5:                          llama.block_count u32              = 32
# llama_model_loader: - kv   6:                  llama.feed_forward_length u32              = 14336
# ...

# %%
from llama_cpp import Llama

# Opção 1: usando Q4_K_M (recomendado para ~1 GB RAM)
llm = Llama(
    #model_path="./models/tinyllama-1.1b-chat-v1.0.Q4_K_M.gguf",  # ← caminho real aqui!
    model_path=r"C:\Users\Yuan\AppData\Local\nomic.ai\GPT4All\Meta-Llama-3-8B-Instruct.Q4_0.gguf",
    n_ctx=2048,           # ou 1024 se der out of memory
    n_threads=4,          # ajuste para sua CPU
    n_gpu_layers=0,       # 0 = só CPU; se tiver GPU NVIDIA, teste -1 ou 20-35
    verbose=True
)

# Teste simples
resposta = llm(
    "Você é um assistente útil. Conte uma piada curta em português.",
    max_tokens=100,
    temperature=0.7,
    echo=True
)

print(resposta["choices"][0]["text"])
# Out:
# llama_model_loader: loaded meta data with 23 key-value pairs and 291 tensors from C:\Users\Yuan\AppData\Local\nomic.ai\GPT4All\Meta-Llama-3-8B-Instruct.Q4_0.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = dl
# llama_model_loader: - kv   2:                           llama.vocab_size u32              = 128256
# llama_model_loader: - kv   3:                       llama.context_length u32              = 8192
# llama_model_loader: - kv   4:                     llama.embedding_length u32              = 4096
# llama_model_loader: - kv   5:                          llama.block_count u32              = 32
# llama_model_loader: - kv   6:                  llama.feed_forward_length u32              = 14336
# ...

# %%
from llama_cpp import Llama

llm = Llama(
    model_path=r"C:\Users\Yuan\AppData\Local\nomic.ai\GPT4All\Meta-Llama-3-8B-Instruct.Q4_0.gguf",
    n_gpu_layers=-1,           # tenta usar GPU ao máximo
    n_ctx=2048,
    verbose=True               # ← isso é essencial
)

# Se quiser testar logo em seguida:
print("Modelo carregado. Veja o log acima para confirmar o backend.")
# Out:
# llama_model_loader: loaded meta data with 23 key-value pairs and 291 tensors from C:\Users\Yuan\AppData\Local\nomic.ai\GPT4All\Meta-Llama-3-8B-Instruct.Q4_0.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = dl
# llama_model_loader: - kv   2:                           llama.vocab_size u32              = 128256
# llama_model_loader: - kv   3:                       llama.context_length u32              = 8192
# llama_model_loader: - kv   4:                     llama.embedding_length u32              = 4096
# llama_model_loader: - kv   5:                          llama.block_count u32              = 32
# llama_model_loader: - kv   6:                  llama.feed_forward_length u32              = 14336
# ...

# %%
print(llm.metadata)
# Out:
# {'general.name': 'dl', 'general.architecture': 'llama', 'llama.block_count': '32', 'llama.vocab_size': '128256', 'llama.context_length': '8192', 'llama.rope.dimension_count': '128', 'llama.embedding_length': '4096', 'llama.feed_forward_length': '14336', 'llama.attention.head_count': '32', 'tokenizer.ggml.eos_token_id': '128009', 'general.file_type': '2', 'llama.attention.head_count_kv': '8', 'llama.attention.layer_norm_rms_epsilon': '0.000010', 'llama.rope.freq_base': '500000.000000', 'tokenizer.ggml.model': 'gpt2', 'general.quantization_version': '2', 'tokenizer.ggml.bos_token_id': '128000', 'tokenizer.ggml.add_bos_token': 'true', 'tokenizer.chat_template': "{% set loop_messages = messages %}{% for message in loop_messages %}{% set content = '<|start_header_id|>' + message['role'] + '<|end_header_id|>\n\n'+ message['content'] | trim + '<|eot_id|>' %}{{ content }}{% endfor %}{% if add_generation_prompt %}{{ '<|start_header_id|>assistant<|end_header_id|>\n\n' }}{% endif %}"}

# %%
from llama_cpp import Llama

print("Tentando carregar o modelo com verbose=True...\n")

try:
    llm = Llama(
        model_path=r"C:\Users\Yuan\AppData\Local\nomic.ai\GPT4All\Meta-Llama-3-8B-Instruct.Q4_0.gguf",
        n_gpu_layers=-1,           # tenta usar GPU (Vulkan)
        n_ctx=2048,
        verbose=True
    )
    print("\nModelo carregou sem erro imediato.")
    print("Procure no texto acima por 'Vulkan', 'ggml_vulkan', 'device: AMD' ou 'offloading ... to GPU'")

except Exception as e:
    print("Erro ao carregar o modelo:")
    print(e)
# Out:
# llama_model_loader: loaded meta data with 23 key-value pairs and 291 tensors from C:\Users\Yuan\AppData\Local\nomic.ai\GPT4All\Meta-Llama-3-8B-Instruct.Q4_0.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = dl
# llama_model_loader: - kv   2:                           llama.vocab_size u32              = 128256
# llama_model_loader: - kv   3:                       llama.context_length u32              = 8192
# llama_model_loader: - kv   4:                     llama.embedding_length u32              = 4096
# llama_model_loader: - kv   5:                          llama.block_count u32              = 32
# llama_model_loader: - kv   6:                  llama.feed_forward_length u32              = 14336
# ...

# %%
from llama_cpp import Llama

llm = Llama(r"C:\Users\Yuan\AppData\Local\nomic.ai\GPT4All\Meta-Llama-3-8B-Instruct.Q4_0.gguf", 
    n_gpu_layers=-1,           # -1 = tenta colocar tudo na GPU
    n_ctx=4096,
    verbose=True               # ← ESSA LINHA É CRUCIAL
)
# Out:
# llama_model_loader: loaded meta data with 23 key-value pairs and 291 tensors from C:\Users\Yuan\AppData\Local\nomic.ai\GPT4All\Meta-Llama-3-8B-Instruct.Q4_0.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = dl
# llama_model_loader: - kv   2:                           llama.vocab_size u32              = 128256
# llama_model_loader: - kv   3:                       llama.context_length u32              = 8192
# llama_model_loader: - kv   4:                     llama.embedding_length u32              = 4096
# llama_model_loader: - kv   5:                          llama.block_count u32              = 32
# llama_model_loader: - kv   6:                  llama.feed_forward_length u32              = 14336
# ...

# %%
import llama_cpp
print("llama_cpp.__version__:", llama_cpp.__version__)
print("llama_cpp has Vulkan support?", hasattr(llama_cpp, "ggml_vulkan"))
print("GGUF backends:", [b for b in dir(llama_cpp) if b.startswith("ggml_")])
# Out:
# llama_cpp.__version__: 0.2.77
# llama_cpp has Vulkan support? False
# GGUF backends: ['ggml_abort_callback', 'ggml_backend_sched_eval_callback']

# %%
from llama_cpp import Llama

llm = Llama(
    model_path=r"C:\Users\Yuan\AppData\Local\nomic.ai\GPT4All\Meta-Llama-3-8B-Instruct.Q4_0.gguf",
    n_gpu_layers=999,           # número bem alto para forçar tudo na GPU
    n_ctx=4096,
    verbose=True
)
# Out:
# llama_model_loader: loaded meta data with 23 key-value pairs and 291 tensors from C:\Users\Yuan\AppData\Local\nomic.ai\GPT4All\Meta-Llama-3-8B-Instruct.Q4_0.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = dl
# llama_model_loader: - kv   2:                           llama.vocab_size u32              = 128256
# llama_model_loader: - kv   3:                       llama.context_length u32              = 8192
# llama_model_loader: - kv   4:                     llama.embedding_length u32              = 4096
# llama_model_loader: - kv   5:                          llama.block_count u32              = 32
# llama_model_loader: - kv   6:                  llama.feed_forward_length u32              = 14336
# ...

# %%
import llama_cpp
print("llama_cpp.__version__:", llama_cpp.__version__)
print("llama_cpp has Vulkan support?", hasattr(llama_cpp, "ggml_vulkan"))
print("GGUF backends:", [b for b in dir(llama_cpp) if b.startswith("ggml_")])
# Out:
# llama_cpp.__version__: 0.3.16
# llama_cpp has Vulkan support? False
# GGUF backends: ['ggml_abort_callback', 'ggml_backend_sched_eval_callback']

# %%
import llama_cpp

# Check if Vulkan is in the supported backends
print("Vulkan support:", llama_cpp.llama_supports_gpu_offload())

# Or check the build info
print(llama_cpp.llama_print_system_info().decode())


import llama_cpp

# Check for Vulkan-specific attributes or constants
print(dir(llama_cpp))  # Look for Vulkan-related attributes
# Out:
# Vulkan support: False
# CPU : SSE3 = 1 | SSSE3 = 1 | AVX = 1 | AVX2 = 1 | F16C = 1 | FMA = 1 | LLAMAFILE = 1 | OPENMP = 1 | REPACK = 1 |
# ...

# %%
llama_print_system_info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 llama_print_system_info()
#
# NameError: name 'llama_print_system_info' is not defined

# %%
import lmstudio as lms

model = lms.llm(r"C:\Users\Yuan\AppData\Local\nomic.ai\GPT4All\Meta-Llama-3-8B-Instruct.Q4_0.gguf")
result = model.respond("What is the meaning of life?")

print(result)

LMStudioClientError: LM Studio is not reachable at any default port. Is LM Studio running?
# Out:
# ---------------------------------------------------------------------------
# LMStudioClientError                       Traceback (most recent call last)
# Cell In[8], line 3
#       1 import lmstudio as lms
# ----> 3 model = lms.llm(r"C:\Users\Yuan\AppData\Local\nomic.ai\GPT4All\Meta-Llama-3-8B-Instruct.Q4_0.gguf")
#       4 result = model.respond("What is the meaning of life?")
#       6 print(result)
#
# LMStudioClientError: LM Studio is not reachable at any default port. Is LM Studio running?
