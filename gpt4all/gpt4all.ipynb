# %%
#pip install gpt4all

# %%
from gpt4all import GPT4All

from gpt4all import GPT4All

model = GPT4All(
    r"C:\Users\Yuan\AppData\Local\nomic.ai\GPT4All\Meta-Llama-3-8B-Instruct.Q4_0.gguf",
    device="gpu"
)

with model.chat_session():
    print(model.generate(
        "o que é rag em AI? explica para mim em português",
        max_tokens=1024
    ))
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from gpt4all import GPT4All
model = GPT4All("./tinyllama-1.1b-chat-v1.0.Q4_K_M.gguf")
                #device="gpu") # downloads / loads a 4.66GB LLM
                device="gpu",          # ou "cpu" se GPU der erro
                #n_gpu_layers=999,      # força usar GPU
                #n_ctx=4096,
                #verbose=True)
with model.chat_session():
    print(model.generate("o que é rag em AI? explica para mim em português", max_tokens=1024))
# Out:
# Found model file at 'C:\\Users\\Yuan\\AppData\\Local\\nomic.ai\\GPT4All\\Meta-Llama-3-8B-Instruct.Q4_0.gguf'
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import torch

print("PyTorch version:", torch.__version__)
print("ROCm/HIP disponível?", torch.version.hip is not None)
print("Número de GPUs detectadas:", torch.cuda.device_count())

if torch.cuda.is_available():
    print("\nGPU detectada:")
    print("Nome da GPU:", torch.cuda.get_device_name(0))
    print("Índice da GPU:", torch.cuda.current_device())
    
    # Mostra o gfx real (o mais importante para compilar)
    gfx = torch.cuda.get_device_properties(0).gcnArch
    print("Arquitetura gfx (para compilar):", gfx)
else:
    print("Nenhuma GPU AMD/ROCm detectada pelo PyTorch.")
# Out:
# PyTorch version: 2.9.0+rocmsdk20251116
# ROCm/HIP disponível? True
# Número de GPUs detectadas: 1
#
# GPU detectada:
# Nome da GPU: AMD Radeon RX 9060 XT
# Índice da GPU: 0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 13
#      10     print("Índice da GPU:", torch.cuda.current_device())
#      12     # Mostra o gfx real (o mais importante para compilar)
# ---> 13     gfx = torch.cuda.get_device_properties(0).gcnArch
#      14     print("Arquitetura gfx (para compilar):", gfx)
#      15 else:
#
# AttributeError: 'torch._C._CudaDeviceProperties' object has no attribute 'gcnArch'
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# ...

# %%
from gpt4all import GPT4All

model = GPT4All(
    r"C:\Users\Yuan\AppData\Local\nomic.ai\GPT4All\Meta-Llama-3-8B-Instruct.Q4_0.gguf",
    device="gpu",          # ou "cpu" se GPU der erro
    #n_gpu_layers=999,      # força usar GPU
    n_ctx=4096,
    verbose=True
)

with model.chat_session():
    resposta = model.generate(
        "o que é RAG em AI? explica em português",
        max_tokens=1024
    )
    print(resposta)
# Out:
# Found model file at 'C:\\Users\\Yuan\\AppData\\Local\\nomic.ai\\GPT4All\\Meta-Llama-3-8B-Instruct.Q4_0.gguf'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 from gpt4all import GPT4All
# ----> 3 model = GPT4All(
#       4     r"C:\Users\Yuan\AppData\Local\nomic.ai\GPT4All\Meta-Llama-3-8B-Instruct.Q4_0.gguf",
#       5     device="gpu",          # ou "cpu" se GPU der erro
#       6     #n_gpu_layers=999,      # força usar GPU
#       7     n_ctx=4096,
#       8     verbose=True
#       9 )
#      11 with model.chat_session():
#      12     resposta = model.generate(
#      13         "o que é RAG em AI? explica em português",
#      14         max_tokens=1024
#      15     )
#
# ...
